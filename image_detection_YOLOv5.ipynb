# %% [markdown]
# <a href="https://colab.research.google.com/github/zhinoos-adibi/Computer_Vision/blob/main/image_detection_YOLOv5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import torch
import os

# Model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
# Out:
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# requirements: PyYAML>=5.3.1 not found and is required by YOLOv5, attempting auto-update...
# ...
#
# requirements: 1 package updated per /root/.cache/torch/hub/ultralytics_yolov5_master/requirements.txt
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# YOLOv5 🚀 2022-1-30 torch 1.10.0+cu111 CPU
#
# Fusing layers...
# Model Summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...

# %%
# Images
dir = '/content/gdrive/My Drive/images/'
imgs = [dir + f for f in ('1.jpg', '2.jpg', '3.jpg','4.jpg')]  # batch of images

# Inference
results = model(imgs)
results.print()  # or .show(), .save()
exec_path = '/content/gdrive/My Drive/images/'
results.save(os.path.join(exec_path,'YOLOv5_detected'))
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# image 1/4: 810x1080 1 person, 1 chair, 1 laptop, 1 mouse
# image 2/4: 959x1280 5 persons
# image 3/4: 810x1080 3 persons, 2 laptops
# image 4/4: 842x1080 4 persons, 1 bowl, 1 banana, 1 apple, 1 orange, 1 cake, 1 dining table
# Speed: 78.2ms pre-process, 559.3ms inference, 2.1ms NMS per image at shape (4, 3, 512, 640)
# Saved 4 images to /content/gdrive/My Drive/images/YOLOv5_detected

# %%
from IPython.display import display, Image
dir2 = '/content/gdrive/My Drive/images/YOLOv5_detected/'
imgs_output = [dir2 + f for f in ('1.jpg', '2.jpg', '3.jpg','4.jpg')]
for items in imgs_output:
  # print(items)
  # print(type(items))
  display(Image(filename=items))
